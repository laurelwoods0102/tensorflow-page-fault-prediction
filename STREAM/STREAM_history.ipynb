# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import os
import json
import datetime

plt.rcParams["figure.figsize"] = (20, 5)

# %%
model_name = "STREAM"

# %%
timestamp = "20210505-090740"

# %%
train_history = pd.read_csv(f"version/{timestamp}/train_history.csv")
train_history
# Out:
#            loss  categorical_accuracy      val_loss  val_categorical_accuracy
# 0  3.008344e+13              0.000000  5.449230e+13                   0.00000
# 1  1.632096e+14              0.000000  1.785763e+14                   0.00000
# 2  3.924177e+14              0.000000  3.670882e+14                   0.00000
# 3  7.100920e+14              0.000000  6.128581e+14                   0.00000
# 4  1.109620e+15              0.000928  9.104657e+14                   0.99921
# 5  1.590527e+15              0.020401  1.267839e+15                   0.00000

# %%
train_history.plot()
